# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Github
#
# 1. Stars
# 2. Folks
# 3. Watching
# 4. Commit (Time)
# 5. Commit (Format)
# 6. Open Issue (Number)
# 7. Close Issue (Number)
# 8. Issue (Number)
# 9. Issue (Format)
# 10. Language (Programming Language used by the OSS)
# 11. Pull Request (Number)
# 12. Pull Request (Format)
# 13. Unit Test
# 14. Security (one page in the github repo)
# 15. Readme (exist or not; detailed or not)
# 16. Release Cycle
# 17. Contributor
#
# ## Outside
#
# 1. Comments from forums (reddit, stackoverflow, etc.)
# 2. Review by tech website
# 3. Review by some programmers' blog
# 4. Existence of an official website
# 5. Art Design of its official website
# 6. Advertisement of its official website
# 7. Whether or not there is contact information for the maintainer (email, social media, etc.)
# 8. Existence of a good documentation (tutorial and instruction)
# 9. Functionality of the OSS (e.g., if an oss is to help a computer to remotely access and control other computers over the internet, this is a sensitive function)
# 10. Year of the OSS project
# 11. Language (human language used by the oss website, documentation, or maintainers (developers))
# 12. Whether or not the oss is for commercial goal
# 13. The sponsor of the oss project
# 14. Whether or not the company that developed the oss has some blots
# 15. Some third-party scores (e.g., Ubuntu Score)

# %% [markdown]
# 1. stars: usage, popularity
# 2. forks: usage, projects
# 3. watches: usage, popularity
# 4. downloads: usage, popularity
# 5. downstream_dependents: usage, projects
# 6. contributors: contribution, contributor_support
# 7. commit_frequency: contribution, contributor_support
# 8. code_commit_coverage: contribution, contributor_support
# 9. response_time: contribution, maintainer_responsivenessa
# 10. issue_close_rate: contribution, maintainer_responsiveness
# 11. comments: contribution, maintainer_responsiveness
# 12. programming_language: code_quality, modernity
# 13. outdated_dependencies: code_quality, modernity
# 14. days_since_last_version_release: code_quality, modernity
# 15. lines_of_code: code_quality, repo_size
# 16. dependencies: code_quality, repo_size
# 17. dependency_vulnerabilities: code_quality, security
# 18. open_security_issues: code_quality, security
# 19. securities_md_length: code_quality, security
# 20. issue_tags: governance, professionality
# 21. code_of_conduct: governance, community_conduct
# 22. issue_engagement: governance, community_conduct
# 23. governance_md_length: governance, community_conduct

# %%
repository_metrics = {
    "stars": ["usage", "popularity"],
    "forks": ["usage", "projects"],
    "watches": ["usage", "popularity"],
    "downloads": ["usage", "popularity"],
    "downstream_dependents": ["usage", "projects"],
    "contributors": ["contribution", "contributor_support"],
    "commit_frequency": ["contribution", "contributor_support"],
    "code_commit_coverage": ["contribution", "contributor_support"],
    "response_time": ["contribution", "maintainer_responsiveness"],
    "issue_close_rate": ["contribution", "maintainer_responsiveness"],
    "comments": ["contribution", "maintainer_responsiveness"],
    "programming_language": ["code_quality", "modernity"],
    "outdated_dependencies": ["code_quality", "modernity"],
    "days_since_last_version_release": ["code_quality", "modernity"],
    "lines_of_code": ["code_quality", "repo_size"],
    "dependencies": ["code_quality", "repo_size"],
    "dependency_vulnerabilities": ["code_quality", "security"],
    "open_security_issues": ["code_quality", "security"],
    "securities_md_length": ["code_quality", "security"],
    "issue_tags": ["governance", "professionality"],
    "code_of_conduct": ["governance", "community_conduct"],
    "issue_engagement": ["governance", "community_conduct"],
    "governance_md_length": ["governance", "community_conduct"],
}

repository_metrics
# Out:
# {'stars': ['usage', 'popularity'],
#  'forks': ['usage', 'projects'],
#  'watches': ['usage', 'popularity'],
#  'downloads': ['usage', 'popularity'],
#  'downstream_dependents': ['usage', 'projects'],
#  'contributors': ['contribution', 'contributor_support'],
#  'commit_frequency': ['contribution', 'contributor_support'],
#  'code_commit_coverage': ['contribution', 'contributor_support'],
#  'response_time': ['contribution', 'maintainer_responsiveness'],
#  'issue_close_rate': ['contribution', 'maintainer_responsiveness'],
#  'comments': ['contribution', 'maintainer_responsiveness'],
#  'programming_language': ['code_quality', 'modernity'],
#  'outdated_dependencies': ['code_quality', 'modernity'],
#  'days_since_last_version_release': ['code_quality', 'modernity'],
#  'lines_of_code': ['code_quality', 'repo_size'],
#  'dependencies': ['code_quality', 'repo_size'],
#  'dependency_vulnerabilities': ['code_quality', 'security'],
#  'open_security_issues': ['code_quality', 'security'],
#  'securities_md_length': ['code_quality', 'security'],
#  'issue_tags': ['governance', 'professionality'],
#  'code_of_conduct': ['governance', 'community_conduct'],
#  'issue_engagement': ['governance', 'community_conduct'],
#  'governance_md_length': ['governance', 'community_conduct']}

# %% [markdown]
# 1. stars: number, stars
# 2. forks: number, forks
# 3. watches: number, watches
# 4. downloads: number, downloads
# 5. downstream_dependents: number, dependency, utilization
# 6. contributors: number, contributors
# 7. commit_frequency:  commit, time, number
# 8. response_time: comment, issue, time
# 9. issue_close_rate: issue, number, open/close, time
# 10. comments: number, comment
# 11. programming_language: time, programming_language
# 12. outdated_dependencies: time, dependency
# 13. days_since_last_version_release: time, version
# 14. lines_of_code: number, code
# 15. dependencies: number, dependency
# 16. dependency_vulnerabilities: number, dependency, security
# 17. open_security_issues: number, open/close, security
# 18. securities_md_length: doc, size
# 19. issue_tags: issue, format, number
# 20. code_of_conduct: doc, size
# 21. governance_md_length: doc, size
# 22. pull_requests: number, pull_requests
# 23. pull_requests_tags: pull_requests, format, number

# %% [markdown]
# number, time, open/close, format, size, utilization, comment, security

# %%
stars, folks, watching, downloads, downstream_dependents, contributors, commit, issue, pull_request, version, programming_language, dependencies, doc, code

# %%
1. Stars
2. Folks
3. Watching
4. Commit (Time)
5. Commit (Format)
6. Open Issue (Number)
7. Close Issue (Number)
8. Issue (Number)
9. Issue (Format)
10. Language (Programming Language used by the OSS)
11. Pull Request (Number)
12. Pull Request (Format)
13. Unit Test
14. Security (one page in the github repo)
15. Readme (exist or not; detailed or not)
16. Release Cycle
17. Contributor

# %%
features = [
    "stars", "folks", "watching", "downloads", "downstream_dependents", 
    "contributors", "commit", "issue", "pull_request", "version", 
    "programming_language", "dependencies", "doc", "code"
]

dimensions = [
    "number", "time", "open/close", "format", "size", 
    "utilization", "comment", "security"
]

def enumerate_combinations(features, dimensions):
    combinations = []
    for feature in features:
        for dimension in dimensions:
            combination = f"{feature} ({dimension})"
            combinations.append(combination)
    return combinations

potential_metrics = enumerate_combinations(features, dimensions)

for metric in potential_metrics:
    print(metric)
# Out:
# stars (number)
# stars (time)
# stars (open/close)
# stars (format)
# stars (size)
# stars (utilization)
# stars (comment)
# stars (security)
# folks (number)
# folks (time)
# folks (open/close)
# folks (format)
# folks (size)
# folks (utilization)
# folks (comment)
# folks (security)
# watching (number)
# watching (time)
# watching (open/close)
# watching (format)
# watching (size)
# watching (utilization)
# watching (comment)
# watching (security)
# downloads (number)
# downloads (time)
# downloads (open/close)
# downloads (format)
# downloads (size)
# downloads (utilization)
# downloads (comment)
# downloads (security)
# downstream_dependents (number)
# downstream_dependents (time)
# downstream_dependents (open/close)
# downstream_dependents (format)
# downstream_dependents (size)
# downstream_dependents (utilization)
# downstream_dependents (comment)
# downstream_dependents (security)
# contributors (number)
# contributors (time)
# contributors (open/close)
# contributors (format)
# contributors (size)
# contributors (utilization)
# contributors (comment)
# contributors (security)
# commit (number)
# commit (time)
# commit (open/close)
# commit (format)
# commit (size)
# commit (utilization)
# commit (comment)
# commit (security)
# issue (number)
# issue (time)
# issue (open/close)
# issue (format)
# issue (size)
# issue (utilization)
# issue (comment)
# issue (security)
# pull_request (number)
# pull_request (time)
# pull_request (open/close)
# pull_request (format)
# pull_request (size)
# pull_request (utilization)
# pull_request (comment)
# pull_request (security)
# version (number)
# version (time)
# version (open/close)
# version (format)
# version (size)
# version (utilization)
# version (comment)
# version (security)
# programming_language (number)
# programming_language (time)
# programming_language (open/close)
# programming_language (format)
# programming_language (size)
# programming_language (utilization)
# programming_language (comment)
# programming_language (security)
# dependencies (number)
# dependencies (time)
# dependencies (open/close)
# dependencies (format)
# dependencies (size)
# dependencies (utilization)
# dependencies (comment)
# dependencies (security)
# doc (number)
# doc (time)
# doc (open/close)
# doc (format)
# doc (size)
# doc (utilization)
# doc (comment)
# doc (security)
# code (number)
# code (time)
# code (open/close)
# code (format)
# code (size)
# code (utilization)
# code (comment)
# code (security)

# %%
features = [
    "stars", "folks", "watching", "downloads", "downstream_dependents", 
    "contributors", "commit", "issue", "pull_request", "version", 
    "programming_language", "dependencies", "doc", "code"
]

dimensions = [
    "number", "time", "open/close", "format", "size", 
    "utilization", "comment", "security"
]

def enumerate_feature_combinations(features, dimensions):
    combinations = []
    for feature in features:
        for i in range(len(dimensions)):
            for j in range(i + 1, len(dimensions)):
                combination = f"{feature} ({dimensions[i]}, {dimensions[j]})"
                combinations.append(combination)
    return combinations

potential_metric_combinations = enumerate_feature_combinations(features, dimensions)
potential_metric_combinations
# Out:
# ['stars (number, time)',
#  'stars (number, open/close)',
#  'stars (number, format)',
#  'stars (number, size)',
#  'stars (number, utilization)',
#  'stars (number, comment)',
#  'stars (number, security)',
#  'stars (time, open/close)',
#  'stars (time, format)',
#  'stars (time, size)',
#  'stars (time, utilization)',
#  'stars (time, comment)',
#  'stars (time, security)',
#  'stars (open/close, format)',
#  'stars (open/close, size)',
#  'stars (open/close, utilization)',
#  'stars (open/close, comment)',
#  'stars (open/close, security)',
#  'stars (format, size)',
#  'stars (format, utilization)',
#  'stars (format, comment)',
#  'stars (format, security)',
#  'stars (size, utilization)',
#  'stars (size, comment)',
#  'stars (size, security)',
#  'stars (utilization, comment)',
#  'stars (utilization, security)',
#  'stars (comment, security)',
#  'folks (number, time)',
#  'folks (number, open/close)',
#  'folks (number, format)',
#  'folks (number, size)',
#  'folks (number, utilization)',
#  'folks (number, comment)',
#  'folks (number, security)',
#  'folks (time, open/close)',
#  'folks (time, format)',
#  'folks (time, size)',
#  'folks (time, utilization)',
#  'folks (time, comment)',
#  'folks (time, security)',
#  'folks (open/close, format)',
#  'folks (open/close, size)',
#  'folks (open/close, utilization)',
#  'folks (open/close, comment)',
#  'folks (open/close, security)',
#  'folks (format, size)',
#  'folks (format, utilization)',
#  'folks (format, comment)',
#  'folks (format, security)',
#  'folks (size, utilization)',
#  'folks (size, comment)',
#  'folks (size, security)',
#  'folks (utilization, comment)',
#  'folks (utilization, security)',
#  'folks (comment, security)',
#  'watching (number, time)',
#  'watching (number, open/close)',
#  'watching (number, format)',
#  'watching (number, size)',
#  'watching (number, utilization)',
#  'watching (number, comment)',
#  'watching (number, security)',
#  'watching (time, open/close)',
#  'watching (time, format)',
#  'watching (time, size)',
#  'watching (time, utilization)',
#  'watching (time, comment)',
#  'watching (time, security)',
#  'watching (open/close, format)',
#  'watching (open/close, size)',
#  'watching (open/close, utilization)',
#  'watching (open/close, comment)',
#  'watching (open/close, security)',
#  'watching (format, size)',
#  'watching (format, utilization)',
#  'watching (format, comment)',
#  'watching (format, security)',
#  'watching (size, utilization)',
#  'watching (size, comment)',
#  'watching (size, security)',
#  'watching (utilization, comment)',
#  'watching (utilization, security)',
#  'watching (comment, security)',
#  'downloads (number, time)',
#  'downloads (number, open/close)',
#  'downloads (number, format)',
#  'downloads (number, size)',
#  'downloads (number, utilization)',
#  'downloads (number, comment)',
#  'downloads (number, security)',
#  'downloads (time, open/close)',
#  'downloads (time, format)',
#  'downloads (time, size)',
#  'downloads (time, utilization)',
#  'downloads (time, comment)',
#  'downloads (time, security)',
#  'downloads (open/close, format)',
#  'downloads (open/close, size)',
#  'downloads (open/close, utilization)',
#  'downloads (open/close, comment)',
#  'downloads (open/close, security)',
#  'downloads (format, size)',
#  'downloads (format, utilization)',
#  'downloads (format, comment)',
#  'downloads (format, security)',
#  'downloads (size, utilization)',
#  'downloads (size, comment)',
#  'downloads (size, security)',
#  'downloads (utilization, comment)',
#  'downloads (utilization, security)',
#  'downloads (comment, security)',
#  'downstream_dependents (number, time)',
#  'downstream_dependents (number, open/close)',
#  'downstream_dependents (number, format)',
#  'downstream_dependents (number, size)',
#  'downstream_dependents (number, utilization)',
#  'downstream_dependents (number, comment)',
#  'downstream_dependents (number, security)',
#  'downstream_dependents (time, open/close)',
#  'downstream_dependents (time, format)',
#  'downstream_dependents (time, size)',
#  'downstream_dependents (time, utilization)',
#  'downstream_dependents (time, comment)',
#  'downstream_dependents (time, security)',
#  'downstream_dependents (open/close, format)',
#  'downstream_dependents (open/close, size)',
#  'downstream_dependents (open/close, utilization)',
#  'downstream_dependents (open/close, comment)',
#  'downstream_dependents (open/close, security)',
#  'downstream_dependents (format, size)',
#  'downstream_dependents (format, utilization)',
#  'downstream_dependents (format, comment)',
#  'downstream_dependents (format, security)',
#  'downstream_dependents (size, utilization)',
#  'downstream_dependents (size, comment)',
#  'downstream_dependents (size, security)',
#  'downstream_dependents (utilization, comment)',
#  'downstream_dependents (utilization, security)',
#  'downstream_dependents (comment, security)',
#  'contributors (number, time)',
#  'contributors (number, open/close)',
#  'contributors (number, format)',
#  'contributors (number, size)',
#  'contributors (number, utilization)',
#  'contributors (number, comment)',
#  'contributors (number, security)',
#  'contributors (time, open/close)',
#  'contributors (time, format)',
#  'contributors (time, size)',
#  'contributors (time, utilization)',
#  'contributors (time, comment)',
#  'contributors (time, security)',
#  'contributors (open/close, format)',
#  'contributors (open/close, size)',
#  'contributors (open/close, utilization)',
#  'contributors (open/close, comment)',
#  'contributors (open/close, security)',
#  'contributors (format, size)',
#  'contributors (format, utilization)',
#  'contributors (format, comment)',
#  'contributors (format, security)',
#  'contributors (size, utilization)',
#  'contributors (size, comment)',
#  'contributors (size, security)',
#  'contributors (utilization, comment)',
#  'contributors (utilization, security)',
#  'contributors (comment, security)',
#  'commit (number, time)',
#  'commit (number, open/close)',
#  'commit (number, format)',
#  'commit (number, size)',
#  'commit (number, utilization)',
#  'commit (number, comment)',
#  'commit (number, security)',
#  'commit (time, open/close)',
#  'commit (time, format)',
#  'commit (time, size)',
#  'commit (time, utilization)',
#  'commit (time, comment)',
#  'commit (time, security)',
#  'commit (open/close, format)',
#  'commit (open/close, size)',
#  'commit (open/close, utilization)',
#  'commit (open/close, comment)',
#  'commit (open/close, security)',
#  'commit (format, size)',
#  'commit (format, utilization)',
#  'commit (format, comment)',
#  'commit (format, security)',
#  'commit (size, utilization)',
#  'commit (size, comment)',
#  'commit (size, security)',
#  'commit (utilization, comment)',
#  'commit (utilization, security)',
#  'commit (comment, security)',
#  'issue (number, time)',
#  'issue (number, open/close)',
#  'issue (number, format)',
#  'issue (number, size)',
#  'issue (number, utilization)',
#  'issue (number, comment)',
#  'issue (number, security)',
#  'issue (time, open/close)',
#  'issue (time, format)',
#  'issue (time, size)',
#  'issue (time, utilization)',
#  'issue (time, comment)',
#  'issue (time, security)',
#  'issue (open/close, format)',
#  'issue (open/close, size)',
#  'issue (open/close, utilization)',
#  'issue (open/close, comment)',
#  'issue (open/close, security)',
#  'issue (format, size)',
#  'issue (format, utilization)',
#  'issue (format, comment)',
#  'issue (format, security)',
#  'issue (size, utilization)',
#  'issue (size, comment)',
#  'issue (size, security)',
#  'issue (utilization, comment)',
#  'issue (utilization, security)',
#  'issue (comment, security)',
#  'pull_request (number, time)',
#  'pull_request (number, open/close)',
#  'pull_request (number, format)',
#  'pull_request (number, size)',
#  'pull_request (number, utilization)',
#  'pull_request (number, comment)',
#  'pull_request (number, security)',
#  'pull_request (time, open/close)',
#  'pull_request (time, format)',
#  'pull_request (time, size)',
#  'pull_request (time, utilization)',
#  'pull_request (time, comment)',
#  'pull_request (time, security)',
#  'pull_request (open/close, format)',
#  'pull_request (open/close, size)',
#  'pull_request (open/close, utilization)',
#  'pull_request (open/close, comment)',
#  'pull_request (open/close, security)',
#  'pull_request (format, size)',
#  'pull_request (format, utilization)',
#  'pull_request (format, comment)',
#  'pull_request (format, security)',
#  'pull_request (size, utilization)',
#  'pull_request (size, comment)',
#  'pull_request (size, security)',
#  'pull_request (utilization, comment)',
#  'pull_request (utilization, security)',
#  'pull_request (comment, security)',
#  'version (number, time)',
#  'version (number, open/close)',
#  'version (number, format)',
#  'version (number, size)',
#  'version (number, utilization)',
#  'version (number, comment)',
#  'version (number, security)',
#  'version (time, open/close)',
#  'version (time, format)',
#  'version (time, size)',
#  'version (time, utilization)',
#  'version (time, comment)',
#  'version (time, security)',
#  'version (open/close, format)',
#  'version (open/close, size)',
#  'version (open/close, utilization)',
#  'version (open/close, comment)',
#  'version (open/close, security)',
#  'version (format, size)',
#  'version (format, utilization)',
#  'version (format, comment)',
#  'version (format, security)',
#  'version (size, utilization)',
#  'version (size, comment)',
#  'version (size, security)',
#  'version (utilization, comment)',
#  'version (utilization, security)',
#  'version (comment, security)',
#  'programming_language (number, time)',
#  'programming_language (number, open/close)',
#  'programming_language (number, format)',
#  'programming_language (number, size)',
#  'programming_language (number, utilization)',
#  'programming_language (number, comment)',
#  'programming_language (number, security)',
#  'programming_language (time, open/close)',
#  'programming_language (time, format)',
#  'programming_language (time, size)',
#  'programming_language (time, utilization)',
#  'programming_language (time, comment)',
#  'programming_language (time, security)',
#  'programming_language (open/close, format)',
#  'programming_language (open/close, size)',
#  'programming_language (open/close, utilization)',
#  'programming_language (open/close, comment)',
#  'programming_language (open/close, security)',
#  'programming_language (format, size)',
#  'programming_language (format, utilization)',
#  'programming_language (format, comment)',
#  'programming_language (format, security)',
#  'programming_language (size, utilization)',
#  'programming_language (size, comment)',
#  'programming_language (size, security)',
#  'programming_language (utilization, comment)',
#  'programming_language (utilization, security)',
#  'programming_language (comment, security)',
#  'dependencies (number, time)',
#  'dependencies (number, open/close)',
#  'dependencies (number, format)',
#  'dependencies (number, size)',
#  'dependencies (number, utilization)',
#  'dependencies (number, comment)',
#  'dependencies (number, security)',
#  'dependencies (time, open/close)',
#  'dependencies (time, format)',
#  'dependencies (time, size)',
#  'dependencies (time, utilization)',
#  'dependencies (time, comment)',
#  'dependencies (time, security)',
#  'dependencies (open/close, format)',
#  'dependencies (open/close, size)',
#  'dependencies (open/close, utilization)',
#  'dependencies (open/close, comment)',
#  'dependencies (open/close, security)',
#  'dependencies (format, size)',
#  'dependencies (format, utilization)',
#  'dependencies (format, comment)',
#  'dependencies (format, security)',
#  'dependencies (size, utilization)',
#  'dependencies (size, comment)',
#  'dependencies (size, security)',
#  'dependencies (utilization, comment)',
#  'dependencies (utilization, security)',
#  'dependencies (comment, security)',
#  'doc (number, time)',
#  'doc (number, open/close)',
#  'doc (number, format)',
#  'doc (number, size)',
#  'doc (number, utilization)',
#  'doc (number, comment)',
#  'doc (number, security)',
#  'doc (time, open/close)',
#  'doc (time, format)',
#  'doc (time, size)',
#  'doc (time, utilization)',
#  'doc (time, comment)',
#  'doc (time, security)',
#  'doc (open/close, format)',
#  'doc (open/close, size)',
#  'doc (open/close, utilization)',
#  'doc (open/close, comment)',
#  'doc (open/close, security)',
#  'doc (format, size)',
#  'doc (format, utilization)',
#  'doc (format, comment)',
#  'doc (format, security)',
#  'doc (size, utilization)',
#  'doc (size, comment)',
#  'doc (size, security)',
#  'doc (utilization, comment)',
#  'doc (utilization, security)',
#  'doc (comment, security)',
#  'code (number, time)',
#  'code (number, open/close)',
#  'code (number, format)',
#  'code (number, size)',
#  'code (number, utilization)',
#  'code (number, comment)',
#  'code (number, security)',
#  'code (time, open/close)',
#  'code (time, format)',
#  'code (time, size)',
#  'code (time, utilization)',
#  'code (time, comment)',
#  'code (time, security)',
#  'code (open/close, format)',
#  'code (open/close, size)',
#  'code (open/close, utilization)',
#  'code (open/close, comment)',
#  'code (open/close, security)',
#  'code (format, size)',
#  'code (format, utilization)',
#  'code (format, comment)',
#  'code (format, security)',
#  'code (size, utilization)',
#  'code (size, comment)',
#  'code (size, security)',
#  'code (utilization, comment)',
#  'code (utilization, security)',
#  'code (comment, security)']
